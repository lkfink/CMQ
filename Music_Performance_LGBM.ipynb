# %% [markdown]
# # **Music Performance During the Coronavirus: LGBM**

# %%
import numpy as np, pandas as pd, os, sys, itertools, re, warnings, math, scipy as sp, lightgbm as lgb, sklearn, shap, matplotlib.pyplot as plt, matplotlib.cm as cm, statsmodels.stats.api as sms, statsmodels.api as sm
from sklearn import preprocessing, metrics, manifold
from sklearn.model_selection import GridSearchCV, KFold, cross_val_score, train_test_split, RandomizedSearchCV
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error, make_scorer, confusion_matrix, plot_confusion_matrix, classification_report 
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.compat import lzip
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.graphics.regressionplots import plot_leverage_resid2
from IPython.display import Image, HTML
from matplotlib.ticker import NullFormatter

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
# %matplotlib inline
plt.rcParams['figure.figsize'] = (14,4)
warnings.filterwarnings(action='ignore')
os.chdir("/Users/home/Desktop/Research/Coronavirus/Public GitHub/")
# %run Coronavirus_Music_Functions.ipynb

# %% [markdown]
# ### **Data**

# %%
with open("/Users/home/Desktop/Research/Coronavirus/Public GitHub/cleaned_data.csv", encoding="utf8", errors='ignore') as file:
    all_data = pd.read_csv(file)
all_data = all_data.drop(columns = ['Unnamed: 0','ID'], axis = 1).reset_index(drop=True)
    
no_listening = [string for string in all_data.columns if not any(substring in string for substring in ['Music Listening', 'Formats'])]
all_data = all_data[no_listening].reset_index(drop=True)
all_data = all_data.reindex(sorted(all_data.columns), axis=1)

# drop individuals who did not complete the performance portion or answer the hypotheses
performance_list = [c for c in all_data.columns if 'Making Music' in c]
data = all_data.dropna(subset=performance_list, how='all').reset_index(drop = True)

h_list = ['_Feel Connected to Others', '_Helps Me Cope', '_Serve as Social Interaction']
h_cols = [c for c in data.columns if any(h in c for h in h_list)]
data = data.dropna(subset=h_cols, how='any').reset_index(drop = True)
data.columns = data.columns.str.replace("Making Music_", "")
data = data.rename(columns={"Country_Country Name": "Country"})
old_columns = data.columns.tolist()

# remove columns with more than 20% missing data
data = remove_columns(data, 20)
new_columns = data.columns.tolist()
columns_with_missing_data = set(old_columns) - set(new_columns)
print(columns_with_missing_data)

# impute missing values by country
normalize_column = 'Country'
cols_to_impute = [x for x in data.columns if x != normalize_column]

for i, column in enumerate(cols_to_impute):
    data[column] = data.groupby(normalize_column, sort = False)[column].apply(lambda x: x.fillna(x.median()))
    
data.reset_index(inplace = True, drop = True)
# Out:
# 1.2 percent of cols with > 20 % missing data
# {'Demographics_Health_Bored'}

# %%
# average hypotheses columns
hypotheses = ['Hypotheses_Feel Connected to Others', 'Hypotheses_Helps Me Cope', 'Hypotheses_Serve as Social Interaction']

cor = data[hypotheses].corr().unstack().sort_values(kind="quicksort", ascending = False)
cor = pd.DataFrame(cor)
cor.columns = ['correlation']
print(cor[cor.correlation < 1], "\n")

data['avg_h'] = (data.loc[:,hypotheses]).mean(axis=1)

print(100*(len(data.loc[data['avg_h'] > 4,:])/len(data)), "% of people who scored > 4")
data = data.drop(columns = ['Hypotheses_Feel Connected to Others', 'Hypotheses_Helps Me Cope', 
                            'Hypotheses_Serve as Social Interaction'], axis = 1).reset_index(drop = True)

data['Country'] = data.Country.astype('category').cat.codes
h_avg = data.pop('avg_h')
# Out:
#                                                                                correlation
# Hypotheses_Helps Me Cope               Hypotheses_Feel Connected to Others        0.741498
# Hypotheses_Feel Connected to Others    Hypotheses_Helps Me Cope                   0.741498
# Hypotheses_Serve as Social Interaction Hypotheses_Feel Connected to Others        0.732678
# Hypotheses_Feel Connected to Others    Hypotheses_Serve as Social Interaction     0.732678
# Hypotheses_Serve as Social Interaction Hypotheses_Helps Me Cope                   0.726054
# Hypotheses_Helps Me Cope               Hypotheses_Serve as Social Interaction     0.726054
#
# 56.94729637234771 % of people who scored > 4

# %% [markdown]
# #### **Linearity Assumptions**

# %%
# Multicollinearity
X = data.copy()
X = sm.add_constant(X)
y = h_avg

vif = pd.Series([variance_inflation_factor(X.values, i) for i in range(X.shape[1])], index=X.columns)
len(vif[vif > 5]), vif[vif > 5]
# Out:
# (25,
#  Country_City Type-No Response                                                inf
#  Country_City Type-Rural                                                      inf
#  Country_City Type-Suburban                                                   inf
#  Country_City Type-Urban                                                      inf
#  Demographics_COVID_Work Changed Binary                                  5.145378
#  Demographics_General_Employement Before COVID-Employed Full Time             inf
#  Demographics_General_Employement Before COVID-Employed Part Time             inf
#  Demographics_General_Employement Before COVID-Home Maker Caregiver           inf
#  Demographics_General_Employement Before COVID-Not Employed                   inf
#  Demographics_General_Employement Before COVID-Prefer Not To Say              inf
#  Demographics_General_Employement Before COVID-Retired                        inf
#  Demographics_General_Employement Before COVID-Self Employed                  inf
#  Demographics_General_Employement Before COVID-Student                        inf
#  Demographics_Health_COVID Contact Binary                              131.098083
#  Demographics_Health_Infected with COVID-No Response                   158.625536
#  Demographics_Health_Infected with COVID-None                          120.909636
#  Demographics_Health_Infected with COVID-Prefer Not To Say              20.253100
#  Demographics_Music_Making Music-Alone                                        inf
#  Demographics_Music_Making Music-Both Alone And Together                      inf
#  Demographics_Music_Making Music-No Response                                  inf
#  Demographics_Music_Making Music-Together                                     inf
#  Music Engagement_Music Type-No Response                                      inf
#  Music Engagement_Music Types-Other Genres                                    inf
#  Music Engagement_Music Types-Other Musicians Composers                       inf
#  Music Engagement_Music Types-Same Musicians Composers                        inf
#  dtype: float64)

# %%
avg_ols_model = sm.OLS(y, X)
avg_results = avg_ols_model.fit()
avg_results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  avg_h   R-squared:                       0.567
# Model:                            OLS   Adj. R-squared:                  0.543
# Method:                 Least Squares   F-statistic:                     23.99
# Date:                Wed, 04 Nov 2020   Prob (F-statistic):               0.00
# Time:                        16:09:19   Log-Likelihood:                -4290.6
# No. Observations:                2922   AIC:                             8885.
# Df Residuals:                    2770   BIC:                             9794.
# Df Model:                         151
# Covariance Type:            nonrobust
# =======================================================================================================================================
#                                                                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------------------------------
# const                                                                  -0.3272      0.388     -0.843      0.399      -1.088       0.433
# Activities_Call People                                                 -0.0052      0.017     -0.301      0.764      -0.039       0.029
# Activities_Cleaning                                                     0.0098      0.018      0.540      0.589      -0.026       0.045
# Activities_Cooking                                                     -0.0039      0.018     -0.216      0.829      -0.040       0.032
# Activities_Crafting                                                     0.0029      0.017      0.167      0.867      -0.031       0.037
# Activities_Create Online Content                                       -0.0227      0.019     -1.222      0.222      -0.059       0.014
# Activities_Drugs or Alcohol                                             0.0152      0.018      0.851      0.395      -0.020       0.050
# Activities_Exercise Indoors                                            -0.0306      0.016     -1.909      0.056      -0.062       0.001
# Activities_Exercise Outdoors                                           -0.0010      0.014     -0.071      0.944      -0.028       0.026
# Activities_Fashion                                                      0.0188      0.015      1.248      0.212      -0.011       0.048
# Activities_Gardening                                                    0.0096      0.018      0.539      0.590      -0.025       0.045
# Activities_Learning New Skills                                          0.0239      0.018      1.361      0.174      -0.011       0.058
# Activities_Making Music                                                 0.0143      0.018      0.816      0.415      -0.020       0.049
# Activities_Meditating                                                  -0.0019      0.018     -0.101      0.920      -0.038       0.034
# Activities_Online Dating                                               -0.0234      0.019     -1.234      0.217      -0.061       0.014
# Activities_Photography                                                 -0.0090      0.017     -0.521      0.603      -0.043       0.025
# Activities_Playing Games                                               -0.0165      0.017     -0.957      0.339      -0.050       0.017
# Activities_Reading Books                                                0.0063      0.018      0.354      0.723      -0.029       0.041
# Activities_Searching for Music Info                                    -0.0044      0.019     -0.226      0.821      -0.042       0.033
# Activities_Sexual Activity                                              0.0037      0.017      0.215      0.830      -0.030       0.037
# Activities_Shopping Online                                             -0.0199      0.014     -1.436      0.151      -0.047       0.007
# Activities_Social Media                                                 0.0048      0.018      0.273      0.785      -0.030       0.039
# Activities_Thinking About Music                                         0.0531      0.019      2.790      0.005       0.016       0.090
# Activities_Virtual Exhibitions                                         -0.0101      0.018     -0.559      0.576      -0.046       0.025
# Activities_Visit People in Person                                       0.0084      0.012      0.691      0.490      -0.015       0.032
# Activities_Volunteering                                                 0.0141      0.016      0.862      0.389      -0.018       0.046
# Activities_Watching Movies                                             -0.0031      0.019     -0.165      0.869      -0.040       0.034
# Activities_Watching News                                                0.0137      0.017      0.823      0.411      -0.019       0.046
# Activities_Writing                                                     -0.0241      0.019     -1.259      0.208      -0.062       0.013
# Country_City Type-No Response                                          -0.1977      0.181     -1.094      0.274      -0.552       0.157
# Country_City Type-Rural                                                -0.0341      0.110     -0.309      0.757      -0.250       0.182
# Country_City Type-Suburban                                             -0.0945      0.109     -0.864      0.387      -0.309       0.120
# Country_City Type-Urban                                                -0.0009      0.110     -0.008      0.994      -0.218       0.216
# Country                                                                 0.0029      0.026      0.112      0.911      -0.048       0.054
# Country_Economic Support Index                                         -0.0007      0.002     -0.406      0.685      -0.004       0.003
# Country_Government Response Index                                       0.0140      0.005      3.096      0.002       0.005       0.023
# Demographics_COVID_Current Place Home                                   0.0027      0.111      0.024      0.981      -0.214       0.219
# Demographics_COVID_Living Situation-Alone                               0.0205      0.082      0.249      0.803      -0.141       0.182
# Demographics_COVID_Living Situation-Child                               0.1149      0.052      2.225      0.026       0.014       0.216
# Demographics_COVID_Living Situation-Elderly                            -0.0039      0.152     -0.026      0.979      -0.302       0.294
# Demographics_COVID_Living Situation-Friend                              0.0684      0.141      0.483      0.629      -0.209       0.346
# Demographics_COVID_Living Situation-No Response                      2.328e-15   2.73e-15      0.854      0.393   -3.02e-15    7.67e-15
# Demographics_COVID_Living Situation-Other                               0.0869      0.192      0.452      0.651      -0.290       0.464
# Demographics_COVID_Living Situation-Parent                             -0.0371      0.067     -0.557      0.578      -0.168       0.094
# Demographics_COVID_Living Situation-Partner                            -0.0712      0.063     -1.128      0.259      -0.195       0.053
# Demographics_COVID_Living Situation-Pet                                 0.0150      0.052      0.287      0.774      -0.088       0.118
# Demographics_COVID_Living Situation-Shared                             -0.0908      0.142     -0.642      0.521      -0.368       0.187
# Demographics_COVID_Living Situation-SibCous                             0.0396      0.122      0.326      0.745      -0.199       0.278
# Demographics_COVID_Number Times Leave                                  -0.0074      0.005     -1.412      0.158      -0.018       0.003
# Demographics_COVID_Ways Work Affected-Homeschool Children               0.0753      0.082      0.920      0.357      -0.085       0.236
# Demographics_COVID_Ways Work Affected-Job At Risk                       0.1280      0.079      1.610      0.107      -0.028       0.284
# Demographics_COVID_Ways Work Affected-Lost Job                          0.0158      0.078      0.203      0.839      -0.137       0.168
# Demographics_COVID_Ways Work Affected-Lower Income                     -0.0629      0.061     -1.039      0.299      -0.182       0.056
# Demographics_COVID_Ways Work Affected-No Response                   -8.706e-16    8.5e-16     -1.024      0.306   -2.54e-15    7.96e-16
# Demographics_COVID_Ways Work Affected-Now Work From Home                0.0443      0.064      0.696      0.487      -0.080       0.169
# Demographics_COVID_Ways Work Affected-Reduced Hours                     0.0087      0.064      0.136      0.892      -0.116       0.133
# Demographics_COVID_Ways Work Affected-Still Go To Work                  0.0290      0.079      0.366      0.715      -0.126       0.184
# Demographics_COVID_Ways Work Affected-Still Work From Home              0.0824      0.072      1.141      0.254      -0.059       0.224
# Demographics_COVID_Work Changed Binary                                 -0.0184      0.092     -0.200      0.842      -0.199       0.162
# Demographics_General_Age                                               -0.0034      0.002     -1.623      0.105      -0.007       0.001
# Demographics_General_Education Categorical                              0.0106      0.042      0.255      0.798      -0.071       0.092
# Demographics_General_Education Years                                   -0.0039      0.005     -0.824      0.410      -0.013       0.005
# Demographics_General_Employement Before COVID-Employed Full Time        0.0177      0.074      0.241      0.810      -0.127       0.162
# Demographics_General_Employement Before COVID-Employed Part Time       -0.1059      0.086     -1.230      0.219      -0.275       0.063
# Demographics_General_Employement Before COVID-Home Maker Caregiver     -0.1416      0.114     -1.245      0.213      -0.365       0.081
# Demographics_General_Employement Before COVID-No Response           -6.352e-17   2.33e-16     -0.273      0.785    -5.2e-16    3.93e-16
# Demographics_General_Employement Before COVID-Not Employed             -0.0477      0.092     -0.520      0.603      -0.228       0.132
# Demographics_General_Employement Before COVID-Prefer Not To Say        -0.0121      0.259     -0.047      0.963      -0.519       0.495
# Demographics_General_Employement Before COVID-Retired                   0.0908      0.100      0.909      0.363      -0.105       0.287
# Demographics_General_Employement Before COVID-Self Employed            -0.0272      0.095     -0.286      0.775      -0.214       0.159
# Demographics_General_Employement Before COVID-Student                  -0.1011      0.099     -1.020      0.308      -0.295       0.093
# Demographics_General_Gender                                             0.0254      0.044      0.583      0.560      -0.060       0.111
# Demographics_Health_Anxious                                            -0.0145      0.022     -0.645      0.519      -0.058       0.030
# Demographics_Health_Arousal                                             0.0599      0.019      3.161      0.002       0.023       0.097
# Demographics_Health_COVID Contact Binary                               -0.3616      0.512     -0.707      0.480      -1.365       0.642
# Demographics_Health_Depressed                                           0.0091      0.021      0.439      0.661      -0.032       0.050
# Demographics_Health_General Health                                      0.0261      0.019      1.381      0.167      -0.011       0.063
# Demographics_Health_Infected with COVID-I Am Infected                  -0.0762      0.113     -0.675      0.500      -0.297       0.145
# Demographics_Health_Infected with COVID-I Am Mourning A Loss           -0.0726      0.108     -0.672      0.502      -0.284       0.139
# Demographics_Health_Infected with COVID-I Have Professional Contact     0.0340      0.098      0.347      0.728      -0.158       0.226
# Demographics_Health_Infected with COVID-I Live With Someone             0.1163      0.113      1.034      0.301      -0.104       0.337
# Demographics_Health_Infected with COVID-No Response                    -0.3666      0.507     -0.724      0.469      -1.360       0.627
# Demographics_Health_Infected with COVID-None                           -0.6204      0.504     -1.232      0.218      -1.608       0.367
# Demographics_Health_Infected with COVID-Prefer Not To Say              -0.7228      0.504     -1.434      0.152      -1.711       0.266
# Demographics_Health_Infected with COVID-Someone I Am Close To          -0.0972      0.097     -1.000      0.317      -0.288       0.093
# Demographics_Health_Lonely                                              0.0068      0.018      0.388      0.698      -0.028       0.041
# Demographics_Health_Negative Valence                                    0.0007      0.022      0.030      0.976      -0.043       0.044
# Demographics_Health_Positive Valence                                    0.0027      0.020      0.135      0.893      -0.037       0.042
# Demographics_Health_Stressed                                            0.0099      0.023      0.431      0.667      -0.035       0.055
# Demographics_Music_Making Music-Alone                                  -0.0580      0.104     -0.556      0.578      -0.263       0.147
# Demographics_Music_Making Music-Both Alone And Together                 0.0514      0.111      0.462      0.644      -0.167       0.270
# Demographics_Music_Making Music-No Response                            -0.3540      0.128     -2.759      0.006      -0.606      -0.102
# Demographics_Music_Making Music-Together                                0.0334      0.109      0.306      0.760      -0.181       0.248
# Demographics_Music_Music Importance                                     0.0962      0.018      5.246      0.000       0.060       0.132
# Demographics_Music_Number of Concerts                                   0.0317      0.014      2.242      0.025       0.004       0.059
# Demographics_Music_Ollen                                                0.0593      0.021      2.781      0.005       0.017       0.101
# Demographics_Personality_Agreeableness                                  0.0619      0.022      2.817      0.005       0.019       0.105
# Demographics_Personality_Conscientiousness                             -0.0776      0.021     -3.648      0.000      -0.119      -0.036
# Demographics_Personality_Extraversion                                   0.0164      0.020      0.838      0.402      -0.022       0.055
# Demographics_Personality_Neuroticism                                    0.0254      0.019      1.303      0.193      -0.013       0.064
# Demographics_Personality_Openness                                      -0.0052      0.021     -0.250      0.802      -0.046       0.035
# Functions_Creates a Personal Space                                      0.0017      0.027      0.063      0.950      -0.051       0.055
# Functions_Enables Me to Vent Negative Emotions                          0.0019      0.025      0.076      0.939      -0.047       0.051
# Functions_Energizes Me                                                  0.0247      0.027      0.900      0.368      -0.029       0.079
# Functions_Feel Connected to My Culture                                 -0.0360      0.026     -1.384      0.166      -0.087       0.015
# Functions_Feel Less Lonely                                              0.0378      0.024      1.571      0.116      -0.009       0.085
# Functions_Feel Like I Am Sharing My Experience                          0.0558      0.026      2.170      0.030       0.005       0.106
# Functions_Feel Like I Have Company                                      0.0119      0.027      0.442      0.658      -0.041       0.065
# Functions_Feel Like I Understand Others                                 0.0504      0.028      1.813      0.070      -0.004       0.105
# Functions_Feel Like Part of a Bigger Group                              0.0627      0.023      2.680      0.007       0.017       0.109
# Functions_Gives Me New Perspectives                                     0.0072      0.028      0.259      0.796      -0.047       0.062
# Functions_Gives Me Sense of Control                                     0.0132      0.028      0.479      0.632      -0.041       0.067
# Functions_Gives Meaning to My Life                                      0.0092      0.027      0.345      0.730      -0.043       0.061
# Functions_Helps Distract Me                                             0.0718      0.027      2.666      0.008       0.019       0.125
# Functions_Helps Keep a Routine                                         -0.0214      0.024     -0.873      0.383      -0.069       0.027
# Functions_Helps Me Accept My Situation                                  0.0169      0.028      0.601      0.548      -0.038       0.072
# Functions_Helps Me Concentrate                                          0.0415      0.025      1.677      0.094      -0.007       0.090
# Functions_Helps Me Dwell on My Worries                                 -0.0342      0.019     -1.765      0.078      -0.072       0.004
# Functions_Helps Me Express My Identity                                  0.0398      0.027      1.490      0.136      -0.013       0.092
# Functions_Helps Me Fall Asleep                                         -0.0704      0.022     -3.269      0.001      -0.113      -0.028
# Functions_Helps Me Identify with the Artist                            -0.0205      0.023     -0.873      0.383      -0.067       0.026
# Functions_Helps Me Relax                                                0.0870      0.031      2.809      0.005       0.026       0.148
# Functions_Helps Me Understand My Feelings                               0.0370      0.025      1.471      0.141      -0.012       0.086
# Functions_Helps Time Pass Quickly                                       0.0023      0.025      0.094      0.925      -0.046       0.050
# Functions_Is Enjoyable                                                  0.0444      0.027      1.620      0.105      -0.009       0.098
# Functions_Lets Me Daydream                                             -0.0138      0.024     -0.571      0.568      -0.061       0.034
# Functions_Makes Me Feel Good About Myself                              -0.0123      0.029     -0.425      0.671      -0.069       0.044
# Functions_Makes Me Want to Move                                        -0.0486      0.022     -2.205      0.028      -0.092      -0.005
# Functions_Moves Me Emotionally                                         -0.0367      0.025     -1.458      0.145      -0.086       0.013
# Functions_Provides Comfort                                              0.0141      0.028      0.500      0.617      -0.041       0.069
# Functions_Provides a Good Background                                    0.0041      0.026      0.161      0.872      -0.046       0.054
# Functions_Provides a Spiritual Experience                              -0.0034      0.023     -0.145      0.885      -0.049       0.042
# Functions_Provides an Aesthetic Experience                              0.0120      0.024      0.498      0.619      -0.035       0.059
# Functions_Puts Me in a Good Mood                                        0.0571      0.027      2.114      0.035       0.004       0.110
# Functions_Reduces My Stress                                             0.0081      0.027      0.297      0.766      -0.046       0.062
# Functions_Reminiscent of Positive Times                                 0.0134      0.026      0.511      0.609      -0.038       0.065
# Functions_Stimulates Me Intellectually                                 -0.0026      0.026     -0.101      0.919      -0.053       0.048
# Functions_Supports Me in a Bad Mood                                     0.0320      0.030      1.054      0.292      -0.028       0.091
# Situations_Balconies                                                   -0.0069      0.023     -0.301      0.764      -0.052       0.038
# Situations_Dance Alone                                                  0.0083      0.021      0.394      0.694      -0.033       0.050
# Situations_Dance Internet                                              -0.0029      0.025     -0.116      0.908      -0.052       0.046
# Situations_Dance Together                                              -0.0220      0.022     -0.996      0.319      -0.065       0.021
# Situations_Make Own Music                                               0.0315      0.024      1.298      0.194      -0.016       0.079
# Situations_Perform For Others                                          -0.0050      0.023     -0.218      0.827      -0.049       0.040
# Situations_Play Alone                                                  -0.0038      0.024     -0.159      0.874      -0.051       0.043
# Situations_Play Internet                                                0.0057      0.028      0.205      0.838      -0.049       0.060
# Situations_Play Together                                               -0.0631      0.025     -2.560      0.011      -0.111      -0.015
# Situations_Post Recordings                                              0.0355      0.025      1.423      0.155      -0.013       0.084
# Situations_Sing Alone                                                   0.0276      0.021      1.311      0.190      -0.014       0.069
# Situations_Sing Internet                                               -0.0220      0.025     -0.865      0.387      -0.072       0.028
# Situations_Sing Together                                                0.0307      0.023      1.329      0.184      -0.015       0.076
# Music Engagement_Diversity of Music                                     0.0221      0.019      1.165      0.244      -0.015       0.059
# Music Engagement_Engaging With Music Differently YN                    -0.0054      0.048     -0.112      0.911      -0.100       0.090
# Music Engagement_Interest in Others Music                               0.2118      0.014     15.209      0.000       0.185       0.239
# Music Engagement_Music Type-No Response                                -0.2545      0.104     -2.439      0.015      -0.459      -0.050
# Music Engagement_Music Types-Other Genres                              -0.0370      0.111     -0.334      0.738      -0.254       0.180
# Music Engagement_Music Types-Other Musicians Composers                 -0.1111      0.119     -0.935      0.350      -0.344       0.122
# Music Engagement_Music Types-Same Musicians Composers                   0.0755      0.134      0.564      0.573      -0.187       0.338
# Music Engagement_Nostalgic Music                                       -0.0005      0.018     -0.028      0.978      -0.036       0.035
# ==============================================================================
# Omnibus:                      288.555   Durbin-Watson:                   1.969
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              464.179
# Skew:                          -0.713   Prob(JB):                    1.60e-101
# Kurtosis:                       4.334   Cond. No.                     6.18e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.23e-26. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
# Normality and autocorrelation of residuals
pred_val = avg_results.fittedvalues.copy()
true_val = y.values.copy()
residual = true_val - pred_val

fig, ax = plt.subplots(figsize=(8,6))
_ = ax.scatter(residual, pred_val)

fig, ax = plt.subplots(figsize=(8,6))
_, (__, ___, r) = sp.stats.probplot(residual, plot=ax, fit=True)

print(r**2)

plot_acf(avg_results.resid, title='ACF of residual errors')
plt.show()
# Out:
# 0.9666822319776305

# %%
# Data are normally distributed: Jarque-Bera
name = ['Jarque-Bera', 'Chi^2 two-tail prob.', 'Skew', 'Kurtosis']
test = sms.jarque_bera(avg_results.resid)
lzip(name, test)
# Out:
# [('Jarque-Bera', 464.1788118882067),
#  ('Chi^2 two-tail prob.', 1.6026979826473007e-101),
#  ('Skew', -0.7128239185609682),
#  ('Kurtosis', 4.334198343951924)]

# %%
# Heteroskedasticity: Breush-Pagan test
name = ['Lagrange multiplier statistic', 'p-value',
        'f-value', 'f p-value']
test = sms.het_breuschpagan(avg_results.resid, X)
lzip(name, test)
# Out:
# [('Lagrange multiplier statistic', 248.9046805752633),
#  ('p-value', 5.263408823932845e-06),
#  ('f-value', 1.7081320431460953),
#  ('f p-value', 3.721709851595646e-07)]

# %%
# Leverage/Outliers
sm.graphics.plot_leverage_resid2(avg_results)
plt.show()

# %% [markdown]
# #### **LightGBM**

# %%
dv = h_avg
h_avg_lgbmr = lgbmr_model(dv, data)
# Out:
# 0.0 % of correlations > 0.90
#
# Best parameters found by grid search are: LGBMRegressor(learning_rate=0.05, max_depth=30, min_child_samples=10,
#               num_leaves=40, random_state=123, subsample_for_bin=500)
#
# =================================
# LightGBM Regression_r2: 0.4408
# LightGBM Regression_Mean_squared_error: 1.3106
# LightGBM Regression_Mean_absolute_error: 0.8355

# %% [markdown]
# ### **SHAP Plots**
# https://github.com/slundberg/shap/blob/master/README.md
#
# SHAP: average of marginal contributions across all permutations.

# %%
# load JS visualization code to notebook
shap.initjs()

regressor = h_avg_lgbmr
X = data.copy()

# explain the model's predictions using SHAP
explainer = shap.TreeExplainer(regressor)
shap_values = explainer.shap_values(X)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...

# %% [markdown]
# **Mean absolute value of the SHAP values for each feature to get a standard bar plot**

# %%
# Simple Feature Importance
shap.summary_plot(shap_values, X, plot_type="bar")

# %% [markdown]
# **To get an overview of which features are most important for a model we can plot the SHAP values of every feature for every sample. The plot above sorts features by the sum of SHAP value magnitudes over all samples, and uses SHAP values to show the distribution of the
# impacts each feature has on the model output. The color represents the feature value (red high, blue low).**

# %%
# Shap plot -- summarize the effects of ALL features
shap.summary_plot(shap_values, X)
